# %% [markdown]
# <div style="display:block">
#     <div style="width: 20%; display: inline-block; text-align: left;">
#     </div>
#     <div style="width: 59%; display: inline-block">
#         <h1  style="text-align: center">Twitter API Pull codes</h1>
#         <div style="width: 100%; text-align: center; display: inline-block;"><i>Author:</i> <strong>Uthra V </strong>
#      </div>
#     </div>
# </div>

# %% [markdown]
# ### Importing packages

# %%
# For sending GET requests from the API
import requests
# For saving access tokens and for file management when creating and adding to the dataset
import os
# For dealing with json responses we receive from the API
import json
# For displaying the data after
import pandas as pd
# For saving the response data in CSV format
import csv
# For parsing the dates received from twitter in readable formats
import datetime
import dateutil.parser
import unicodedata
#To add wait time between requests
import time

# %%
import tweepy

# %% [markdown]
# ### Authentication of twitter creds

# %%
consumer_key = "CdmjmzkpOMcVxYhQlmcvPOENq"  ##same as api key
consumer_secret = "AAAAAAAAAAAAAAAAAAAAAG8OjAEAAAAAyoELN7eav3qA3OvzBzc1oLb6aKg%3DDSpeQjhvPXeiTtTAkCvnshM1J1Y3jCg0eIo1sXC3NkcbPYtHe0"  ##same as api secret
access_key = "982928536473427968-0DbN2Fz6Wi6OtNSJX53M008mhMQUMN9"
access_secret = "NSG8vveg7GNamzPaQ3ok5lseAGq1kJzF5fv8AHPKR48uZ"

# %%
# Twitter authentication
# auth = tweepy.OAuthHandler(consumer_key, consumer_secret)   
# auth.set_access_token(access_key, access_secret) 
auth = tweepy.OAuth2BearerHandler("AAAAAAAAAAAAAAAAAAAAAG8OjAEAAAAAyoELN7eav3qA3OvzBzc1oLb6aKg%3DDSpeQjhvPXeiTtTAkCvnshM1J1Y3jCg0eIo1sXC3NkcbPYtHe0")   
# Creating an API object 
api = tweepy.API(auth)

# %%
AAAAAAAAAAAAAAAAAAAAAAm1iAEAAAAAYPmLyOUP%2FammXBwhvuDxmijbtC8%3DkuCLEvwIcZZbTMt5kSATZQuGsYuzAZl76W9jn6fJaAxIK0igLn

# %% [markdown]
# ### Pulling desired data from Twitter

# %%
username_tweets = tweepy.Cursor(api.search_tweets, q=('Virat Kohli','Kohli','Virat'), until = '2022-11-11',tweet_mode='extended').items(5000)

# %%
data = []
for tweet in username_tweets:
    text = tweet._json
    data.append(text)

# %%
import pandas as pd
df = pd.DataFrame(data)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Thu Nov 10 23:59:51 +0000 2022  1590856794959642628  1590856794959642628
# 1  Thu Nov 10 23:59:47 +0000 2022  1590856781072596992  1590856781072596992
# 2  Thu Nov 10 23:59:47 +0000 2022  1590856778425995264  1590856778425995264
# 3  Thu Nov 10 23:59:42 +0000 2022  1590856758259781632  1590856758259781632
# 4  Thu Nov 10 23:59:28 +0000 2022  1590856700810366977  1590856700810366977
#
#                                            full_text  truncated  \
# 0        RT @YoursHari_B: @Cricketracker Virat Kohli      False
# 1  RT @ItzThanesh: "Someone will come and probabl...      False
# 2  If whole world is against team India,then too,...      False
# 3  RT @AkshatOM10: Virat Kohli deserve better.\n\...      False
# 4  RT @AkshatOM10: Virat Kohli deserve better.\n\...      False
#
#   display_text_range                                           entities  \
# ...

# %%
df.shape
# Out:
# (5000, 32)

# %%
df.to_csv("Twitter_data_sample_ViratKohli_Nov10.csv")

# %%
df['user'].head(1)
# Out:
# 0    {'id': 1574387120386543616, 'id_str': '1574387...
# Name: user, dtype: object

# %% [markdown]
# ### The same process was repeated for Nov 2nd and Nov 6th datasets
